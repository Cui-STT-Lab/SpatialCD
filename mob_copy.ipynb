# %%
import pandas as pd
import os
import logging

# %%
from spatialcd.evaluation.evaluation import compute_num_rare

# %%
from spatialcd.lda.model import train
from spatialcd.utils.function import *

# %%
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
PATH_TO_MODELS = '/Users/phuong/Library/CloudStorage/OneDrive-MichiganStateUniversity/Projects/spatialDC/example/output/'
os.makedirs(PATH_TO_MODELS, exist_ok=True)

# %%
PATH_TO_DATA = '/Users/phuong/Library/CloudStorage/OneDrive-MichiganStateUniversity/Projects/spatialDC/data/'
sample_name = 'MOB'
corpus, pos = load_single_sample(PATH_TO_DATA, sample_id=sample_name, corpus_file='mob_corpus.csv', pos_file='mob_pos.csv')

from spatialcd.spatial.graph_construction import knn_graph_single_sample
n_neighbors = 4
knn_graph_matrix = knn_graph_single_sample(pos, n_neighbors, sample_name)

# %%
n_topics = 12

# %%
spatialdc_model = train(
                corpus=corpus,
                graph_matrices= knn_graph_matrix,
                nu_penalty= 10,
                n_topics=n_topics
                )
# Out:
# HBox(children=(IntProgress(value=0, description='LDA training', style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Update alphas', max=1, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='LDA training', style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Update alphas', max=1, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='LDA training', style=ProgressStyle(description_width='initial…
# HBox(children=(IntProgress(value=0, description='Update alphas', max=1, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='LDA training', style=ProgressStyle(description_width='initial…

# %%
save_spatialdc_results(spatialdc_model, n_topics, n_neighbors, corpus, PATH_TO_MODELS)
# Out:
# 2025-09-30 14:29:05,713 - INFO - Results saved to /Users/phuong/Library/CloudStorage/OneDrive-MichiganStateUniversity/Projects/spatialDC/example/output/ppxt_spatialdc_topics=12_knn=4.csv
